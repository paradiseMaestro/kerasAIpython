# %%
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2

# plt.imshow(np.squeeze(style_image))
# plt.show()
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')
def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    # print('----')
    # print(img)


    return img


# content_image = load_image('1.jpg')
# style_image = load_image('2.jpg')
# stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
# cv2.imwrite('generated_img.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))


i = 0 
while( i <= 18):
  # pass
  content_image = load_image('h.jpg')
  style_image = load_image('g/'+str(i)+'.jpg')
  stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
  cv2.imwrite('i/generated_img'+str(i)+'.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
  i = i + 1
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-1-a684d009aaed> in <module>()
#      30   # pass
#      31   content_image = load_image('h.jpg')
# ---> 32   style_image = load_image('g/'+str(i)+'.jpg')
#      33   stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
#      34   cv2.imwrite('i/generated_img'+str(i)+'.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
#
# <ipython-input-1-a684d009aaed> in load_image(img_path)
#       9 model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')
#      10 def load_image(img_path):
# ---> 11     img = tf.io.read_file(img_path)
#      12     img = tf.image.decode_image(img, channels=3)
#      13     img = tf.image.convert_image_dtype(img, tf.float32)
#
# ...
