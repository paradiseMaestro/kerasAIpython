# %%
import keras 
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils

model = Sequential()

model.add(Dense(32, activation='relu', input_dim=3))

model.add(Dense(3, activation='softmax'))

model.compile(optimizer='rmsprop',

              loss="categorical_crossentropy",

              metrics=['accuracy'])

import numpy as np

data = np.random.random((1000, 3))
prim = np.random.random((1, 3))

labels = np.random.randint(3, size=(1000, 1))
one_hot_labels = keras.utils.np_utils.to_categorical(labels, num_classes=3)

model.fit(data, one_hot_labels, epochs=10, batch_size=32)
# prim[0].reshape((1, 28, 100, 1))

    
# print(prim)



print( model.predict(prim) )
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 3ms/step - loss: 1.1026 - accuracy: 0.3650
# Epoch 2/10
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0985 - accuracy: 0.3620
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0977 - accuracy: 0.3650
# Epoch 4/10
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0971 - accuracy: 0.3650
# Epoch 5/10
# 32/32 [==============================] - 0s 4ms/step - loss: 1.0969 - accuracy: 0.3730
# Epoch 6/10
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0967 - accuracy: 0.3730
# Epoch 7/10
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0961 - accuracy: 0.3790
# Epoch 8/10
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0962 - accuracy: 0.3600
# Epoch 9/10
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0956 - accuracy: 0.3730
# Epoch 10/10
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0960 - accuracy: 0.3820
# [[1.0544206e-27 1.0000000e+00 0.0000000e+00]]
