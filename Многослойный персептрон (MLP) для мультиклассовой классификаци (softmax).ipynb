# %%
import keras

from keras.models import Sequential

from keras.layers import Dense, Dropout, Activation

from tensorflow.keras.optimizers import SGD


import numpy as np

x_train = np.random.random((1000, 20))

y_train = keras.utils.np_utils.to_categorical(
np.random.randint(10, size=(1000, 1)), num_classes=10)

x_test = np.random.random((100, 20))

y_test = keras.utils.np_utils.to_categorical(
np.random.randint(10, size=(100, 1)), num_classes=10)

model = Sequential()

model.add(Dense(64, activation='relu', input_dim=20))

model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))


sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy',

              optimizer=sgd,

              metrics=['accuracy'])

model.fit(x_train, y_train,

          epochs=20,

          batch_size=128)

print(
    model.predict(np.random.random((1, 20)))
)

# score = model.evaluate(x_test, y_test, batch_size=128)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 8/8 [==============================] - 1s 3ms/step - loss: 2.4086 - accuracy: 0.0890
# Epoch 2/20
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3555 - accuracy: 0.1160
# Epoch 3/20
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3386 - accuracy: 0.0990
# Epoch 4/20
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3300 - accuracy: 0.1020
# Epoch 5/20
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3189 - accuracy: 0.0980
# Epoch 6/20
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3091 - accuracy: 0.1170
# Epoch 7/20
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3134 - accuracy: 0.1050
# Epoch 8/20
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3102 - accuracy: 0.1180
# Epoch 9/20
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3050 - accuracy: 0.1090
# Epoch 10/20
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2954 - accuracy: 0.1230
# Epoch 11/20
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3045 - accuracy: 0.1110
# Epoch 12/20
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3004 - accuracy: 0.1320
# Epoch 13/20
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3034 - accuracy: 0.1100
# Epoch 14/20
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3007 - accuracy: 0.1270
# Epoch 15/20
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3068 - accuracy: 0.1170
# Epoch 16/20
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2995 - accuracy: 0.1230
# Epoch 17/20
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3034 - accuracy: 0.1160
# Epoch 18/20
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2898 - accuracy: 0.1140
# Epoch 19/20
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3005 - accuracy: 0.1240
# Epoch 20/20
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3002 - accuracy: 0.1170
# [[0.10153612 0.08892416 0.11576774 0.10571361 0.10162875 0.10123599
#   0.08867566 0.09902336 0.1007892  0.09670547]]
